# %%
import requests, pprint, json, os
from datetime import datetime
from pathlib import PurePath, Path
import xml.etree.ElementTree as ET
from lxml import etree
from io import StringIO, BytesIO

pp = pprint.PrettyPrinter(indent=4)

# NYPL API
# main parameters
output_dir = PurePath(os.getcwd(), 'output')
n_pagin = 500
pagin = 'per_page=' + str(n_pagin)
baseurl = 'http://api.repo.nypl.org/api/v1/'
trail_url = '/search?&publicDomainOnly=true&q='
token = '1bt13bkug32reiu4'
auth = 'Token token=' + token

# custom parameters
# s_terms = 'Farm Security Administration Photographs'
# s_terms = 'still image manhattan street portrait 1960 photograph '
s_terms = "Photographs"
adv_s_terms = '&field=genre'
# coll_id = 'e5462600-c5d9-012f-a6a3-58d385a7bc34'  # Farm Security Administration Photographs
# coll_id = 'a301da20-c52e-012f-cc55-58d385a7bc34'  # Photographic views of New York City, 1870's-1970's
coll_id = '439afdd0-c62b-012f-66d1-58d385a7bc34'  # Detroit Publishing Company postcards
# Cf. http://api.repo.nypl.org/api/v1/collections?per_page=200

coll_url = baseurl + 'collections/' + coll_id + '?' + pagin
full_url = baseurl + 'items' + trail_url + s_terms + '&' + pagin + adv_s_terms
item_url = baseurl + 'items/mods_captures/'   # item_details


# data = requests.get(coll_url, headers={'Authorization': auth}).json()['nyplAPI']
# data = requests.get(full_url, headers={'Authorization': auth}).json()['nyplAPI']


# print(rq.keys())
# print(meta.keys())
# check_n_pages = total_results % n_pagin


def timestamp():
    return datetime.utcnow().isoformat()

def create_logfile(log_path):
    """
    Creates a (txt) log file
    """
    if os.path.isfile(log_path):
        os.remove(log_path)
    log_stream = open(log_path, 'w+')
    return log_stream

def write_to_log(log_path, message):
    """
    Writes to (txt) log file
    """
    with open(log_path, 'a') as log:

        if isinstance(message, str):
            mes_str = '\n' + '/!\\ ' + message
            log.write(mes_str)

        elif isinstance(message, list):
            mes_main = '\n' + '/!\\ ' + message[0]
            log.write(mes_main)
            for p in message[1:]:
                mes_p = '\n' + '\t' + ' - ' + p
                log.write(mes_p)


# loop over API
page = 1
n_pages = 1
run_dir = PurePath(output_dir, timestamp())
xml_dir = PurePath(run_dir, 'data', 'xml')
json_dir = PurePath(run_dir, 'data', 'json')
log_dir = PurePath(run_dir, 'log')
log_path = PurePath(log_dir, 'log.txt')

for f in [run_dir, xml_dir, json_dir, log_dir]:
    # os.mkdir(f)
    Path(f).mkdir(parents=True, exist_ok=True)

log_stream = create_logfile(log_path)
while page <= n_pages:
    
    # page
    if page > 1:
        page_url = full_url + '&page=' + str(page)
    else:
        page_url = full_url
    init_mes = '\n--> Page ' + str(page)
    print(init_mes)
    write_to_log(log_path, init_mes)
    
    # data, params
    print(page_url)
    write_to_log(log_path, page_url)
    data = requests.get(page_url, headers={'Authorization': auth}).json()['nyplAPI']
    metata = data['response']['result']
    # metata = data['response']
    
    # prepare page numbers
    if page == 1:
        total_results = int(data['response']['numResults'])
        n_pages = int(total_results / n_pagin)
        if total_results % n_pagin > 0:
            n_pages += 1 
        
        # logs
        mes_res = '{:,}'.format(total_results) + " items retrieved from the search '" + s_terms + "'"
        mes_pages = '\n{:,}'.format(n_pages) + " pages to process"
        print(mes_res, mes_pages)
        write_to_log(log_path, [mes_res, mes_pages])
    
    # loop over items in this page
    total = len(metata)
    for p in range(total):
        
        # preps
        pos = p + (page - 1) * n_pagin
        p_offset = (page-1) * n_pagin + 1
        el = metata[p]
        item_mes = '\n--> Item #' + '{:,}'.format(pos+1) + '/' + '{:,}'.format(total_results)
        print(item_mes)
        write_to_log(log_path, item_mes)
        url = item_url + el['uuid']
        url_xml = url + '.xml'
        filename = 'item_' + str(pos) + '_page_' + str(page)
        print(url)
        write_to_log(log_path, url)
        
        # json
        try:
            data = requests.get(url, headers={'Authorization': auth}).json()['nyplAPI']
            json_f = PurePath(json_dir, filename + '.json')
            with open(json_f, 'w') as f:
                json.dump(data['response'], f)
                log = data['response']['headers']['message']['$']
                # pp.pprint(data['response']['headers']['message'])
                json_mes = '- json file created --> ' + str(log)
                print(json_mes)
                write_to_log(log_path, json_mes)
        except Exception:
            print(Exception)
            print('--> Issue wiht file/url ...')
        
        # xml
        try:
            data = requests.get(url_xml, headers={'Authorization': auth}).text
            xml_f = PurePath(xml_dir, filename + '.xml')
            tree = etree.fromstring(bytes(data, encoding='utf-8'))
            meta_xml = tree.findall('response')[0]
            xml_data = etree.tostring(meta_xml).decode('UTF-8')
            with open(xml_f, "w") as f:
                f.write(xml_data)
                log = tree.findall('response/headers/message')[0].text
                xml_mes = '- xml file created --> ' + log
                print(xml_mes)
                write_to_log(log_path, xml_mes)
        except Exception:
            print(Exception)
            print('--> Issue wiht file/url ...')

    # iterate to next page
    page += 1

# end loop
log_stream.close()
# Out:
# --> Page 1
# http://api.repo.nypl.org/api/v1/items/search?&publicDomainOnly=true&q=Photographs&per_page=500&field=genre
# 138,604 items retrieved from the search 'Photographs'
# 278 pages to process
#
# --> Item #1/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/7d71ff40-b3cb-0132-6b3b-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #2/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/d62998c0-b45c-0132-b812-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #3/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/c91a6ca0-b462-0132-b9ba-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #4/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/6cf6f150-b53e-0132-e134-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #5/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/92bb1610-b54e-0132-aa1c-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #6/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/d4fe0d10-b54f-0132-271f-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #7/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/78a36bf0-b54f-0132-e5af-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #8/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/2ed21650-b553-0132-de0f-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #9/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/a0f15a30-b55a-0132-44de-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #10/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/f99830d0-b55c-0132-3a03-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #11/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/ddbc2e70-b55d-0132-ea70-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #12/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/622b9cb0-b560-0132-10f1-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #13/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/0b44f260-b561-0132-eeb0-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #14/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/c9658440-b5f4-0132-38cf-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #15/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/f7fe9600-b5f4-0132-a957-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #16/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/ad33dc30-b94c-0132-5576-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #17/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/1adcf910-b9e2-0132-696a-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #18/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/7a702c20-ba0e-0132-0340-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #19/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/31972610-ba0f-0132-8b5e-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #20/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/5c8f56a0-ba10-0132-8865-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #21/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/35e49cf0-ba12-0132-c2f5-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #22/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/81dc9c20-bac6-0132-4108-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #23/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/d17a40a0-bac9-0132-e4a9-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #24/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/6ee974c0-bacb-0132-0f34-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #25/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/9f71ba50-bad1-0132-8a5a-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #26/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/91d3cb50-bb8f-0132-8b56-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #27/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/65f2ff30-bb91-0132-ce73-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #28/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/13ae5890-bb94-0132-32c3-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #29/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/4d574710-bb9b-0132-f3b4-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #30/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/f4e80ae0-bb9c-0132-8cdd-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #31/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/c13e4930-bf61-0132-2c33-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #32/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/1c429940-bf7f-0132-bf2a-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #33/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/76bcfd20-c0f4-0132-61f7-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #34/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/bfb20df0-c0f7-0132-413a-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #35/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/74b41030-c0f7-0132-86c5-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #36/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/b8a643b0-c0f9-0132-3dbf-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #37/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/75abbb40-c102-0132-e8ea-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #38/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/649d0960-c102-0132-5bad-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #39/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/d374c1c0-c105-0132-664a-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #40/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/e5e18420-c106-0132-88d2-58d385a7bbd0
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #41/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/fa2ffd80-c10a-0132-fcd9-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #42/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/0f124c70-c124-0132-98c8-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #43/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/6d0fe230-c1c8-0132-fdc3-58d385a7b928
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #44/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47df-848d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #45/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47df-84c3-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #46/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47df-858a-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #47/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47df-858c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #48/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47df-8589-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #49/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47df-8594-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #50/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47e3-b54d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #51/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c491-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #52/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c49d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #53/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c49a-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #54/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c495-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #55/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c45c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #56/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c117-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #57/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c116-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #58/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c457-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #59/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c450-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #60/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c10f-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #61/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c481-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #62/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c118-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #63/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c112-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #64/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1e2-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #65/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c10d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #66/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c111-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #67/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c110-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #68/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c10c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #69/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c10b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #70/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1e3-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #71/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c10a-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #72/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1de-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #73/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1d1-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #74/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1ce-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #75/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1d5-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #76/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1d2-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #77/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1d0-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #78/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1c9-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #79/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1c1-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #80/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1cc-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #81/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1bf-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #82/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1b6-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #83/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1a7-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #84/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1a8-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #85/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1ad-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #86/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1ba-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #87/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b11f-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #88/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b11d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #89/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1b1-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #90/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b119-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #91/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b126-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #92/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b121-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #93/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c123-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #94/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0fb-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #95/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c121-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #96/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0e1-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #97/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0fc-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #98/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0fe-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #99/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0e5-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #100/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0e4-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #101/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0e3-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #102/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-470b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #103/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0c4-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #104/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0e0-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #105/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-d2aa-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #106/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0c6-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #107/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-7a2c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #108/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0c7-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #109/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-54a4-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #110/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-f801-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #111/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-30ed-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #112/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-e7cb-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #113/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-201d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #114/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc9-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #115/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc6-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #116/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b107-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #117/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc8-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #118/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc1-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #119/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc2-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #120/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcbf-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #121/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc95-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #122/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc4-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #123/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc96-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #124/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc98-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #125/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc93-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #126/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc97-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #127/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc90-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #128/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc91-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #129/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc92-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #130/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a06d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #131/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a06b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #132/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a06c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #133/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b10b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #134/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b10e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #135/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b106-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #136/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0fa-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #137/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b100-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #138/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a05f-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #139/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a05e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #140/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b104-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #141/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a052-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #142/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b109-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #143/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0e6-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #144/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a051-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #145/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a050-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #146/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a053-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #147/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a032-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #148/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a031-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #149/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a056-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #150/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a057-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #151/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a054-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #152/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a059-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #153/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a05a-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #154/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a04e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #155/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a04f-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #156/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a058-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #157/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a05b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #158/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c452-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #159/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c44a-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #160/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c449-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #161/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c448-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #162/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c316-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #163/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1ab-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #164/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1ac-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #165/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c2ea-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #166/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c2f4-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #167/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1aa-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #168/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a8-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #169/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a9-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #170/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c453-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #171/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a5-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #172/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c156-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #173/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c155-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #174/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c154-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #175/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c145-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #176/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c150-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #177/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a6-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #178/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c151-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #179/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c153-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #180/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c14c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #181/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c142-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #182/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c140-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #183/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c13d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #184/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c13c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #185/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c152-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #186/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c13b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #187/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c138-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #188/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c44d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #189/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c136-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #190/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c13e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #191/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c135-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #192/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c137-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #193/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c12d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #194/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c132-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #195/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a2-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #196/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c12e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #197/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c454-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #198/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c482-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #199/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c480-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #200/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c12f-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #201/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c128-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #202/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1d9-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #203/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c11a-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #204/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b192-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #205/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c13f-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #206/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1e0-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #207/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1ab-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #208/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c44b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #209/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c126-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #210/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1e1-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #211/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc7-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #212/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-62fd-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #213/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a3-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #214/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c12c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #215/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c119-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #216/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b193-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #217/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b116-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #218/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc3-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #219/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1d7-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #220/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1a9-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #221/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc94-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #222/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a4-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #223/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c148-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #224/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c13a-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #225/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c127-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #226/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c113-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #227/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b1aa-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #228/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dc8f-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #229/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c139-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #230/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dcc5-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #231/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c12b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #232/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c114-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #233/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-dca2-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #234/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a060-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #235/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c1a1-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #236/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b11e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #237/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c115-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #238/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c447-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #239/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0c5-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #240/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c11e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #241/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a05c-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #242/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b0e2-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #243/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c11b-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #244/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-02d6-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #245/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-b111-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #246/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dd-c10e-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #247/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47dc-a05d-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #248/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47d9-c463-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #249/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47d9-c468-a3d9-e040-e00a18064a99
# - json file created --> ok
# - xml file created --> ok
#
# --> Item #250/138,604
# http://api.repo.nypl.org/api/v1/items/mods_captures/510d47d9-c461-a3d9-e040-e00a18064a99
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-44243f4ae8dd> in <module>
#     135         # json
#     136         try:
# --> 137             data = requests.get(url, headers={'Authorization': auth}).json()['nyplAPI']
#     138             json_f = PurePath(json_dir, filename + '.json')
#     139             with open(json_f, 'w') as f:
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
